# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file_path="C:\\Users\\hp\\Downloads\\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(file_path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# continent column value count

# %%
visa_df['continent'].value_counts()
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
visa_df['case_status'].value_counts()
# Out:
# case_status
# Certified    17018
# Denied        8462
# Name: count, dtype: int64

# %%
# Q) out of all Asian applications how many got visa
# out of all Europe applications how many got visa

# %%
c1=visa_df['continent']=='Asia'
c2=visa_df['case_status']=='certified'
visa_df[c1|c2]
#len(visa_df[c1|c2])
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 5         EZYV06      Asia              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
c1=visa_df['continent']=='Asia'
c2=visa_df['case_status']=='certified'
visa_df[c1|c2]
len(visa_df[c1|c2])
# Out:
# 16861

# %%
c1=visa_df['continent']=='Europe'
c2=visa_df['case_status']=='certified'
visa_df[c1|c2]
#len(visa_df[c1|c2])
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 9         EZYV10    Europe             Doctorate                  Y
# 16        EZYV17    Europe              Master's                  Y
# 24        EZYV25    Europe             Doctorate                  Y
# 36        EZYV37    Europe           High School                  Y
# 37        EZYV38    Europe              Master's                  Y
# ...          ...       ...                   ...                ...
# 25435  EZYV25436    Europe            Bachelor's                  N
# 25448  EZYV25449    Europe             Doctorate                  Y
# 25460  EZYV25461    Europe              Master's                  Y
# 25462  EZYV25463    Europe            Bachelor's                  N
# 25466  EZYV25467    Europe            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 9                         N             2251         1995
# ...

# %%
c1=visa_df['continent']=='Europe'
c2=visa_df['case_status']=='certified'
visa_df[c1|c2]
len(visa_df[c1|c2])
# Out:
# 3732

# %%
labels=visa_df['continent'].unique()
labels
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
labels=visa_df['continent'].unique()
for i in labels:
    con1=visa_df['continent']==i
    con2=visa_df['case_status']=='cerified'
    con=con1&con2

# %%
labels=visa_df['continent'].unique()
certified_count=[]
for i in labels:
    con1=visa_df['continent']==i
    con2=visa_df['case_status']=='Certified'
    con=con1&con2
    certified_count.append(len(visa_df[con]))
labels,certified_count

pd.DataFrame(zip(labels,certified_count),columns=['continent','case_status'])
# Out:
#        continent  case_status
# 0           Asia        11012
# 1         Africa          397
# 2  North America         2037
# 3         Europe         2957
# 4  South America          493
# 5        Oceania          122

# %%
labels=visa_df['continent'].unique()
certified_count=[]
denied_count=[]
for i in labels:
    con1=visa_df['continent']==i
    con2=visa_df['case_status']=='Certified'
    con3=visa_df['case_status']=='Denied'
    certified_count.append(len(visa_df[con1&con2]))
    denied_count.append(len(visa_df[con1&con3]))
labels,certified_count,denied_count

pd.DataFrame(zip(labels,certified_count,denied_count),columns=['continent','case_status','denied'])
# Out:
#        continent  case_status  denied
# 0           Asia        11012    5849
# 1         Africa          397     154
# 2  North America         2037    1255
# 3         Europe         2957     775
# 4  South America          493     359
# 5        Oceania          122      70

# %%
pd.DataFrame(zip(labels,certified_count,denied_count),columns=['continent','case_status','denied']).set_index('continent')
# Out:
#                case_status  denied
# continent
# Asia                 11012    5849
# Africa                 397     154
# North America         2037    1255
# Europe                2957     775
# South America          493     359
# Oceania                122      70

# %% [markdown]
# ### pd.crosstab()

# %%
col1=visa_df['continent']
col2=visa_df['case_status']
pd.crosstab(col1,col2)
# Out:
# case_status    Certified  Denied
# continent
# Africa               397     154
# Asia               11012    5849
# Europe              2957     775
# North America       2037    1255
# Oceania              122      70
# South America        493     359

# %%
col1=visa_df['continent']
col2=visa_df['case_status']
result1=pd.crosstab(col1,col2)

# %%
result1.plot(kind='bar')
plt.show()

# %%
result1.plot(kind='barh')
plt.show()

# %%
# continenabst
# Education
# case_status

col1=visa_df['continent']
col2=visa_df['case_status']
col3=visa_df['education_of_employee']
col=[col2,col3]
pd.crosstab(col1,col)
# Out:
# case_status            Certified                                    Denied  \
# education_of_employee Bachelor's Doctorate High School Master's Bachelor's
# continent
# Africa                        81        43          23      250         62
# Asia                        4407       780         676     5149       2761
# Europe                      1040       788         162      967        259
# North America                641       207         210      979        584
# Oceania                       38        19          19       46         28
# South America                160        75          74      184        173
#
# case_status
# education_of_employee Doctorate High School Master's
# continent
# Africa                       11          43       38
# Asia                        143        1614     1331
# Europe                       58         328      130
# North America                51         191      429
# Oceania                       3          17       22
# ...

# %%
col1=visa_df['continent']
col2=visa_df['case_status']
col3=visa_df['education_of_employee']
col=[col2,col3]
result2=pd.crosstab(col1,col)

# %%
result2.plot(kind='bar')
# Out:
# <Axes: xlabel='continent'>

# %%
result2.plot(kind='barh')
# Out:
# <Axes: ylabel='continent'>

# %% [markdown]
# $Numerical-vs-Numerical$

# %% [markdown]
# $plt.scatter$

# %%
x=[1,2,3,4,5,6]
y=[11,12,13,14,15,16]

#(1,11),(2,12),(3,13),(4,14),(5,15),(6,16)

plt.scatter(x,y)

# %%
- scatter plots for only numericals
# Out:
#   Cell In[25], line 1
#     - scatter plots for only numericals
#               ^
# SyntaxError: invalid syntax

# %%
x=[i for i in range(-10,11)]
y=[i*i for i in range(-10,11)]
plt.scatter(x,y)
plt.plot(x,y)

# %%
plt.plot(x,y)

# %%
plt.scatter(visa_df['education_of_employee'],visa_df['prevailing_wage'])

# %%
plt.scatter(visa_df['prevailing_wage'],visa_df['education_of_employee'])

# %%
plt.scatter(visa_df['prevailing_wage'],visa_df['no_of_employees'])

# %%
# covariance- matrix#
# How many numerical variable are there:3
#               no_employee  yr    wage
# no_employee   var          cov   cov
#yr             cov          var   cov
#age            cov          cov   var

# %% [markdown]
# $correlation-coefficient$

# %% [markdown]
# - Denoted with r
# - r range -1 to 1
# - positive relation range=(0,1]
# -  negative relation range=[-1,0]

# %% [markdown]
# <img class="XqHOTb IGEbUc" alt="r =\frac{\sum\left(x_{i}-\bar{x}\right)\left(y_{i}-\bar{y}\right)}{\sqrt{\sum\left(x_{i}-\bar{x}\right)^{2} \sum\left(y_{i}-\bar{y}\right)^{2}}}" src="https://www.gstatic.com/education/formulas2/553212783/en/correlation_coefficient_formula.svg" role="img" data-csiid="25" data-atf="1">

# %% [markdown]
# <img class="XqHOTb IGEbUc" alt="r =\frac{\sum\left(x_{i}-\bar{x}\right)\left(y_{i}-\bar{y}\right)}{\sqrt{\sum\left(x_{i}-\bar{x}\right)^{2} \sum\left(y_{i}-\bar{y}\right)^{2}}}" src="https://www.gstatic.com/education/formulas2/553212783/en/correlation_coefficient_formula.svg" role="img" data-csiid="25" data-atf="1">

# %% [markdown]
# $corr()$

# %%
visa_df.corr(numeric_only=True)  # applicable for you need to see numeric_only

#in the data frame we have both cat and numerical column
# correlation applicable for only numeric column
# Explicity mention numeric=True
#
# if people has pandas old version 
# they dont have numeric_only argument
# for thr visa_df.corr() works
# Out:
#                  no_of_employees  yr_of_estab  prevailing_wage
# no_of_employees         1.000000    -0.017770        -0.009523
# yr_of_estab            -0.017770     1.000000         0.012342
# prevailing_wage        -0.009523     0.012342         1.000000

# %%
pd.__version__
# Out:
# '2.0.3'

# %%
plt.scatter(visa_df['yr_of_estab'],visa_df['prevailing_wage'])

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file_path="C:\\Users\\hp\\Downloads\\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(file_path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# corr function
visa_df.corr(numeric_only=True)
# Out:
#                  no_of_employees  yr_of_estab  prevailing_wage
# no_of_employees         1.000000    -0.017770        -0.009523
# yr_of_estab            -0.017770     1.000000         0.012342
# prevailing_wage        -0.009523     0.012342         1.000000

# %%
# matrix
# showing values in a matrix
# showing values in a picture : Heatmap

# %%
corr_data=visa_df.corr(numeric_only=True)
sns.heatmap(corr_data)
# Out:
# <Axes: >

# %%
corr_data=visa_df.corr(numeric_only=True)
sns.heatmap(corr_data,annot=True)
# Out:
# <Axes: >

# %%
# winequality dataset

# %%
data_file='C:\\Users\\hp\\Downloads\\winequality_red - winequality_red (1).csv'
wine_df=pd.read_csv(data_file)
wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               NaN               NaN          NaN             NaN        NaN
# 1               7.4             0.700         0.00             1.9      0.076
# 2               NaN               NaN          NaN             NaN        NaN
# 3               7.8             0.880         0.00             2.6      0.098
# 4               NaN               NaN          NaN             NaN        NaN
# ...             ...               ...          ...             ...        ...
# 3193            6.3             0.510         0.13             2.3      0.076
# 3194            NaN               NaN          NaN             NaN        NaN
# 3195            5.9             0.645         0.12             2.0      0.075
# 3196            NaN               NaN          NaN             NaN        NaN
# 3197            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(wine_df.corr(),annot=True)
# Out:
# <Axes: >

# %%
data_file='C:\\Users\\hp\\Downloads\\winequality_red - winequality_red (1).csv'
wine_df=pd.read_csv(data_file)
wine_df


wine_df.corr()

plt.figure(figsize=(10,10))
sns.heatmap(wine_df.corr(),annot=True)

#plt.scatter(wine_df['fixed acidity'],wine_df['citric acid'])
# Out:
# <Axes: >

# %%
plt.scatter(wine_df['fixed acidity'],wine_df['citric acid'])

# %%
plt.scatter(wine_df['fixed acidity'],wine_df['pH'])
