# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file_path="C:\\Users\\hp\\Downloads\\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(file_path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# - In machine learning algorithms will develop models by using maths
#
#  - maths allows only numbers
#
# - so it is very important , you need to pass numerical data only
#
# - so we need to convert categorical data to numerical data
#
# - For that we have encoding methods
#
# - Encoding
#
#   - Label Encoder
#
#      - map method
#      - np.where()
#      - LabelEncoder package from sklearn
#
#   - One hot encoder
#
#      - pd.get_dummies()

# %% [markdown]
# ## Label Encoder
#
# #### Map Method

# %% [markdown]
# - read any categorical column: case_status
# - check how many unique labels are there
# - create a dictionary with those unique labels as keys by providing a number as values

# %%
#### Read the data##########################################
file_path="C:\\Users\\hp\\Downloads\\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(file_path)
visa_df

##############################Map#############################

visa_df['case_status'].unique()   # two unique labels are there
dict1={'Certified':0,'Denied':1}
visa_df['case_status'].map(dict1)

# do you want overrite existed column
# do you want create a new column
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 25475    0
# 25476    0
# 25477    0
# 25478    0
# 25479    0
# Name: case_status, Length: 25480, dtype: int64

# %% [markdown]
# ### Create a new column

# %%
#### Read the data##########################################
file_path="C:\\Users\\hp\\Downloads\\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(file_path)
visa_df

##############################Map#############################

visa_df['case_status'].unique()   # two unique labels are there
dict1={'Certified':0,'Denied':1}
visa_df['case_status_num']=visa_df['case_status'].map(dict1)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# ### Drop the column

# %%
visa_df.drop('case_status_num',axis=1,inplace=True)

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# ## overwrite on same column(preferable)

# %%
#### Read the data##########################################
file_path="C:\\Users\\hp\\Downloads\\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(file_path)
visa_df

##############################Map#############################

visa_df['case_status'].unique()   # two unique labels are there
dict1={'Certified':0,'Denied':1}
visa_df['case_status']=visa_df['case_status'].map(dict1)

visa_df
# in the map method inplace=True is not there
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
l1=visa_df['continent'].unique()
l1
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
visa_df['continent'].unique()
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
l1=visa_df['continent'].unique()
dict1={}
for i in range(len(l1)):
    dict1[l1[i]]=i
dict1
# Out:
# {'Asia': 0,
#  'Africa': 1,
#  'North America': 2,
#  'Europe': 3,
#  'South America': 4,
#  'Oceania': 5}

# %%
num=visa_df['continent'].unique()
dict1={}
for i in range(len(num)):
    print(num[i],i)
# Out:
# Asia 0
# Africa 1
# North America 2
# Europe 3
# South America 4
# Oceania 5

# %%
labels=visa_df['continent'].unique()
num=len(visa_df['continent'].unique())
dict1={}
for i in range(num):
    dict1[labels[i]]=i
    
dict1

labels=visa_df['continent'].unique()
num=len(visa_df['continent'].unique())

{labels[i]:i for i in range(num)}
# Out:
# {'Asia': 0,
#  'Africa': 1,
#  'North America': 2,
#  'Europe': 3,
#  'South America': 4,
#  'Oceania': 5}

# %% [markdown]
# ### Method:-2: np.where()

# %%
file_path="C:\\Users\\hp\\Downloads\\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(file_path)
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %% [markdown]
# - np.where() is applicable for binary condition
# - which means it is applicable only for two labels
# - np.where(<condition>,<Truevalue>,<False_value>)
# - for example case_status has two labels
# - condition:  <col_values>=='certified'
# - True value: Replace all certified values with 0
# - False value: Replace all certified values with 1

# %%
visa_df['case_status']=np.where((visa_df['case_status']=='Certified'),0,1)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
con=visa_df['case_status']=='Certified'
visa_df['case_id']=np.where(con,1,0)
visa_df
# Out:
#        case_id continent education_of_employee has_job_experience  \
# 0            0      Asia           High School                  N
# 1            0      Asia              Master's                  Y
# 2            0      Asia            Bachelor's                  N
# 3            0      Asia            Bachelor's                  N
# 4            0    Africa              Master's                  Y
# ...        ...       ...                   ...                ...
# 25475        0      Asia            Bachelor's                  Y
# 25476        0      Asia           High School                  Y
# 25477        0      Asia              Master's                  Y
# 25478        0      Asia              Master's                  Y
# 25479        0      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# ### labels-encoder()

# %% [markdown]
# - LabelEncoder is a method from sklearn
# - under sklearn we have sub models
# - one of the submodule: preprocessing
# - Any sklearn packages we have only 3 steps
#
# - step:-1: read the packages
# - step:-2: save the packages
# - step:-3: apply fit transform

# %%
file_path="C:\\Users\\hp\\Downloads\\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(file_path)
visa_df

# step:-1
from sklearn.preprocessing import LabelEncoder
# step:-2
le=LabelEncoder()
# step:-3
visa_df['case_status']=le.fit_transform(visa_df['case_status'])
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
$fit--Transform:
    - fit and transform two different definations
age: 1 2 3 4 5

nwe age: by adding each observation with mean value : x+mean
# Out:
#   Cell In[34], line 1
#     $fit--Transform:
#     ^
# SyntaxError: invalid syntax

# %%
file_path="C:\\Users\\hp\\Downloads\\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(file_path)
print(visa_df[['continent','case_status']].head(10))

# step:-1
from sklearn.preprocessing import LabelEncoder
# step:-2
le=LabelEncoder()
# step:-3
visa_df['continent']=le.fit_transform(visa_df['continent'])
print(visa_df[['continent','case_status']].head(10))
# Out:
#        continent case_status
# 0           Asia      Denied
# 1           Asia   Certified
# 2           Asia      Denied
# 3           Asia      Denied
# 4         Africa   Certified
# 5           Asia   Certified
# 6           Asia   Certified
# 7  North America      Denied
# 8           Asia   Certified
# 9         Europe   Certified
#    continent case_status
# 0          1      Denied
# 1          1   Certified
# 2          1      Denied
# 3          1      Denied
# 4          0   Certified
# 5          1   Certified
# 6          1   Certified
# 7          3      Denied
# 8          1   Certified
# 9          2   Certified

# %%
print(visa_df['continent'][:5])
le.inverse_transform(visa_df['continent'])
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    0
# Name: continent, dtype: int32
# array(['Asia', 'Asia', 'Asia', ..., 'Asia', 'Asia', 'Asia'], dtype=object)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file_path="C:\\Users\\hp\\Downloads\\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(file_path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# ### one hot encoder

# %% [markdown]
# - one hot encoder means at a time only one will be ON(1/True), others are OFF(0/False)
# - suppose case status has two unique labels
# - certified and denied
# - like below
# - In one hot encoder it will create two new column
# - like below
# |case_status|certified|denied|
# |-----------|---------|------|
# |certified|1|0|
# |denied|0|1|
#
# **Advantages**
#
# - one hot encoder new column are orthogonal to each other
#
# - orthogonality means 90 degrees phase shift
#
# - 90 degrees phase shift means perpendicular each other
#
# - perpendicular means independent each other
#
# - Independent means no relation
#
# - It is very important properties that it is to avoid relation between variables
#
# **Draw Back**
#
# - Assume that you have 100 unique labels for a column
#
# - so it will create 100 new columms
#
# - To process 100 columns we require more memory,more time,more hardware
#
# - This is called curse of Dimensionality

# %% [markdown]
# **pd.get_dummies**

# %%
file_path="C:\\Users\\hp\\Downloads\\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(file_path)
visa_df

pd.get_dummies(visa_df,columns=['case_status'])
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
file_path="C:\\Users\\hp\\Downloads\\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(file_path)
visa_df

pd.get_dummies(visa_df,columns=['continent'])
# Out:
#          case_id education_of_employee has_job_experience  \
# 0         EZYV01           High School                  N
# 1         EZYV02              Master's                  Y
# 2         EZYV03            Bachelor's                  N
# 3         EZYV04            Bachelor's                  N
# 4         EZYV05              Master's                  Y
# ...          ...                   ...                ...
# 25475  EZYV25476            Bachelor's                  Y
# 25476  EZYV25477           High School                  Y
# 25477  EZYV25478              Master's                  Y
# 25478  EZYV25479              Master's                  Y
# 25479  EZYV25480            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# ...

# %%
file_path="C:\\Users\\hp\\Downloads\\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(file_path)
visa_df

pd.get_dummies(visa_df,columns=['continent'],dtype='int')
# Out:
#          case_id education_of_employee has_job_experience  \
# 0         EZYV01           High School                  N
# 1         EZYV02              Master's                  Y
# 2         EZYV03            Bachelor's                  N
# 3         EZYV04            Bachelor's                  N
# 4         EZYV05              Master's                  Y
# ...          ...                   ...                ...
# 25475  EZYV25476            Bachelor's                  Y
# 25476  EZYV25477           High School                  Y
# 25477  EZYV25478              Master's                  Y
# 25478  EZYV25479              Master's                  Y
# 25479  EZYV25480            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# ...
