# %% [markdown]
# - converting skewed distribution to normal distribution
#
# - All maths developed by assumption as data follows Normal Distribution
#
#     - log transformation
#
#     - sqrt transformation
#
#     - exponential transformation
#
#     - box - cox transformation
#
#
#     - reciprocal transformation
#
#
#     - yeo - jhanosn transformation

# %% [markdown]
# **Step:-1**
#
# **Read the Packages**

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Step:-2**
#
# **Read the Data**

# %%
data=np.random.exponential(size=1000)
# we are taking a random values
# 1000 samples we are taking

# %%
plt.hist(data,bins=40,label='Exponential')
plt.show()

# %%
plt.hist(data,bins=40,label='Exponential')
plt.legend()
plt.show()

# %% [markdown]
# **Step:-3**
#
# **Log Transformation**
#
# - np.log represent natural logorithm
#
# - natural logorithm means base e
#
# - exponential will multiply with log base e
#
# - Natural logorithm will works positive data
#
# - log transformation will remove the skew
#
# - it will not convert into Normal Distribution

# %%
log_data=np.log(data)
plt.hist(log_data,bins=40,label='Log transformation')
plt.legend()
plt.show()

# %%
plt.subplot(1,2,1).hist(data,bins=40)
plt.subplot(1,2,2).hist(log_data,bins=40)
plt.show()

# %%
log_log_data=np.log(log_data)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_17428\910739559.py:1: RuntimeWarning: invalid value encountered in log
#   log_log_data=np.log(log_data)

# %% [markdown]
# **Step:-4**
#
# **Reciprocal Transformation**
#
# - If data has zero , it will fail

# %%
rec_data=1/data
plt.hist(rec_data,bins=40,label='Reciprocal transformation')
plt.legend()
plt.show()

# %% [markdown]
# **Step:-5**
#
# **Squareroot Transformation**

# %%
sqrt_data=np.sqrt(data)
plt.hist(sqrt_data,bins=40,label='sqrt transformation')
plt.show()

# %%
sqrt_data=data **(0.5)
plt.hist(sqrt_data,bins=40,label='sqrt transformation')
plt.legend()
plt.show()

# %%
[(1,2),(6,7)]

# %%
import numpy as np
p1 = [1, 2]
p2 = [6, 7]
distance = np.sqrt(((p1[0] - p2[0]) ** 2) + ((p1[1] - p2[1]) ** 2))
print(distance)
# Out:
# 7.0710678118654755

# %%
p1 = [1, 2]
p2 = [6, 7]
distance = np.sqrt(((p1[0] - p2[0]) ** 2) + ((p1[1] - p2[1]) ** 2))
print(distance)

# %%
l=[(1,2),(6,7)]
def dist(l):
    x1=l[0][0]
    y1=l[0][1]
    x2=l[1][0]
    y2=l[1][1]
    return(((x2-x1)**2)+(y2-y1)**2)**(0.5)

dist(l)
# Out:
# 7.0710678118654755

# %% [markdown]
# **Power Transformer**
#
# - it is in sklearn.preprocessing
#
# - method argument
#
# - box-cox
#
# - ye-jhonson

# %%
l=[(1,2),(6,7)]
x1=l[0][0]
y1=l[0][1]
x2=l[1][0]
y2=l[1][1]
print(x1,y1,x2,y2)
# Out:
# 1 2 6 7
